# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# Assume user input
test_input2 = np.array([2,'male',31.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# c:\Users\godsc\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\godsc\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
# As we see using pipeline the production code become so easy and reliable
# For any change in training code we don't have to change the production code
# Just need to download the new pickle file and upload here
