# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.impute import KNNImputer,SimpleImputer
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('../12.1 DATA/train (1).csv',usecols=['Age','Pclass','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived  Pclass   Age     Fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
df.isnull().mean()*100
# Out:
# Survived     0.00000
# Pclass       0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train.head()
# Out:
#      Pclass   Age     Fare
# 30        1  40.0  27.7208
# 10        3   4.0  16.7000
# 873       3  47.0   9.0000
# 182       3   9.0  31.3875
# 876       3  20.0   9.8458

# %%
knn = KNNImputer() 

x_train_trf = knn.fit_transform(x_train)
x_test_trf = knn.transform(x_test)

# %%
ans = []
def check(imputer,weight):
    knn = KNNImputer(n_neighbors=imputer,weights=weight) 

    x_train_trf = knn.fit_transform(x_train)
    x_test_trf = knn.transform(x_test)
    
    pd.DataFrame(x_train_trf,columns=x_train.columns)
    
    lr = LogisticRegression()

    lr.fit(x_train_trf,y_train)

    y_pred = lr.predict(x_test_trf)

    ans.append(accuracy_score(y_test,y_pred))
    
for i in range(1,5):
    check(i,'uniform')
    
print(ans)


ans.clear()
for i in range(1,5):
    check(i,'distance')
    
print(ans)
# Out:
# [0.6871508379888268, 0.7094972067039106, 0.7039106145251397, 0.7039106145251397]
# [0.6871508379888268, 0.7150837988826816, 0.7150837988826816, 0.7094972067039106]

# %%
pd.DataFrame(x_train_trf,columns=x_train.columns)
# Out:
#      Pclass   Age      Fare
# 0       1.0  40.0   27.7208
# 1       3.0   4.0   16.7000
# 2       3.0  47.0    9.0000
# 3       3.0   9.0   31.3875
# 4       3.0  20.0    9.8458
# ..      ...   ...       ...
# 707     3.0  30.0    8.6625
# 708     3.0  24.4    8.7125
# 709     1.0  71.0   49.5042
# 710     1.0  33.6  221.7792
# 711     1.0  42.8   25.9250
#
# [712 rows x 3 columns]

# %%
lr = LogisticRegression()

lr.fit(x_train_trf,y_train)

y_pred = lr.predict(x_test_trf)

accuracy_score(y_test,y_pred)
# Out:
# 0.7039106145251397

# %%
# I wrote a function to try different k neighbours and weights to optimize my solution

# %%
ans = []
def check(imputer,weight):
    knn = KNNImputer(n_neighbors=imputer,weights=weight) 

    x_train_trf = knn.fit_transform(x_train)
    x_test_trf = knn.transform(x_test)
    
    pd.DataFrame(x_train_trf,columns=x_train.columns)
    
    lr = LogisticRegression()

    lr.fit(x_train_trf,y_train)

    y_pred = lr.predict(x_test_trf)

    ans.append(accuracy_score(y_test,y_pred))
    
for i in range(1,5):
    check(i,'uniform')
    
print(ans)


ans.clear()
for i in range(1,5):
    check(i,'distance')
    
print(ans)

# %%
# Compare with simple Imputer --> mean

# %%
si = SimpleImputer()

x_train_trf2 = si.fit_transform(x_train)
x_test_trf2 = si.transform(x_test)

# %%
clf = LogisticRegression()
clf.fit(x_train_trf2,y_train)
y_pred2 = clf.predict(x_test_trf2)
accuracy_score(y_test,y_pred2)
# Out:
# 0.6927374301675978

# %%
# Here knnimputer outshines simpleimputer
