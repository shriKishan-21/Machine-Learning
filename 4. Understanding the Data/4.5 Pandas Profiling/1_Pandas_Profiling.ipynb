# %%
import pandas as pd

# %%
df = pd.read_csv('../4.1 DATA/train (1).csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# !pip install pandas-profiling
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/262.6 kB ? eta -:--:--
#    --------- ------------------------------ 61.4/262.6 kB 1.1 MB/s eta 0:00:01
#    ------------------ --------------------- 122.9/262.6 kB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 245.8/262.6 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 262.6/262.6 kB 1.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    - -------------------------------------- 0.2/4.7 MB 4.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.5/4.7 MB 5.1 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.6/4.7 MB 4.5 MB/s eta 0:00:01
#    ------- -------------------------------- 0.9/4.7 MB 4.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.3/4.7 MB 5.4 MB/s eta 0:00:01
# ...

# %% [markdown]
# ### **pandas_profiling has been renamed and replaced by ydata-profiling**

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#    ---------------------------------------- 0.0/398.7 kB ? eta -:--:--
#    ---- ----------------------------------- 41.0/398.7 kB ? eta -:--:--
#    ---------- ----------------------------- 102.4/398.7 kB 1.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 102.4/398.7 kB 1.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 102.4/398.7 kB 1.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 235.5/398.7 kB 1.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 235.5/398.7 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  389.1/398.7 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 398.7/398.7 kB 1.2 MB/s eta 0:00:00
# ...
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
# ...

# %%
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# Basic profiling
profile = ProfileReport(
    df,
    title="Titanic Dataset - YData Profiling Report",
    explorative=True
)

# %%
profile.to_file("titanic_profiling_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
