# %% [markdown]
# ### **Working with SQL**

# %%
# Here we ude mysql.connector library to connect database to python

# %% [markdown]
# ### 1. **Using mysql.connector library**

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 435.7 kB/s eta 0:00:28
#      --------------------------------------- 0.1/11.9 MB 762.6 kB/s eta 0:00:16
#      --------------------------------------- 0.1/11.9 MB 950.9 kB/s eta 0:00:13
#       --------------------------------------- 0.3/11.9 MB 1.3 MB/s eta 0:00:09
#      - -------------------------------------- 0.4/11.9 MB 1.5 MB/s eta 0:00:08
#      - -------------------------------------- 0.4/11.9 MB 1.4 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/11.9 MB 1.5 MB/s eta 0:00:08
#      -- ------------------------------------- 0.6/11.9 MB 1.6 MB/s eta 0:00:07
#      -- ------------------------------------- 0.7/11.9 MB 1.7 MB/s eta 0:00:07
#      --- ------------------------------------ 0.9/11.9 MB 1.8 MB/s eta 0:00:06
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="world",
    auth_plugin="mysql_native_password")

# %% [markdown]
# Here while using 'connect' problem will arise.
# This is how to handle it->
# 1. Use this code in SQL --
# ALTER USER 'root'@'localhost'
# IDENTIFIED WITH mysql_native_password
# BY 'root';
# 2. Then use this code in SQL --
# FLUSH PRIVILEGES;
# 3. Now write python code as --
# conn = mysql.connector.connect(
#     host="localhost",
#     user="root",
#     password="root",
#     database="worlds",
#     auth_plugin="mysql_native_password"
# )

# %%
pd.read_sql_query("SELECT * FROM country",conn)
# Out:
# C:\Users\godsc\AppData\Local\Temp\ipykernel_5108\858535147.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country",conn)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %% [markdown]
# ### 2. **Using pymysql library**

# %%
# !pip install pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/45.3 kB ? eta -:--:--
#    --------- ------------------------------ 10.2/45.3 kB ? eta -:--:--
#    ------------------ --------------------- 20.5/45.3 kB 217.9 kB/s eta 0:00:01
#    ------------------------------------ --- 41.0/45.3 kB 279.3 kB/s eta 0:00:01
#    ---------------------------------------- 45.3/45.3 kB 280.5 kB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
conn = pymysql.Connect(host="localhost",user="root",password="root",database="world")

# %%
pd.read_sql_query("SELECT * FROM city",conn)
# Out:
# C:\Users\godsc\AppData\Local\Temp\ipykernel_5108\374620591.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city",conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# ...
